# %%
import pandas as pd

# %%
# load data
raw = pd.read_csv("/mnt/c/Users/dzhon/Desktop/myProjects/data/en_fr_trans/train.csv", nrows = 5)

# %%
# Build vocab

# %%
# what is a tokenizer
# input & output

# %%
# embeddings

# %%
# decode embeddings
